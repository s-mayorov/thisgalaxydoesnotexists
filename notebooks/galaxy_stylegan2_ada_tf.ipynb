# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Thu Jun 24 14:03:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

if os.path.isdir("/content/drive/My Drive/colab/thisgalaxydoesnotexists/colab-sg2-ada"):
    # %cd "/content/drive/My Drive/colab/thisgalaxydoesnotexists/colab-sg2-ada/stylega2-ada"
else:
    # %cd "/content/drive/My Drive/colab/thisgalaxydoesnotexists/"
    # !mkdir "colab-sg2-ada"
    # %cd "colab-sg2-ada"
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd "stylegan2-ada"
    # !mkdir "downloads"
    # !mkdir "datasets"
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/colab/thisgalaxydoesnotexists/colab-sg2-ada/stylega2-ada'
# /content

# %%
# %cd "/content/drive/My Drive/colab/thisgalaxydoesnotexists/colab-sg2-ada/stylegan2-ada"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py
# Out:
# /content/drive/My Drive/colab/thisgalaxydoesnotexists/colab-sg2-ada/stylegan2-ada

# %%
zip_path = "/content/drive/My\ Drive/datasets/full_size.zip"
# !unzip {zip_path} -d "/content/"
# Out:
# Archive:  /content/drive/My Drive/datasets/full_size.zip
#    creating: /content/full_size/
#   inflating: /content/full_size/opo9842a.jpg
#   inflating: /content/full_size/potw2109a.jpg
#   inflating: /content/full_size/heic0513c.jpg
#   inflating: /content/full_size/opo1204c.jpg
#   inflating: /content/full_size/potw1143a.jpg
#   inflating: /content/full_size/heic0810bu.jpg
#   inflating: /content/full_size/potw2008a.jpg
#   inflating: /content/full_size/potw1249a.jpg
#   inflating: /content/full_size/opo9910b.jpg
#   inflating: /content/full_size/heic0815h.jpg
#   inflating: /content/full_size/potw1251a.jpg
#   inflating: /content/full_size/heic9902g.jpg
#   inflating: /content/full_size/heic0910s.jpg
#   inflating: /content/full_size/heic0717c.jpg
#   inflating: /content/full_size/heic1311a.jpg
#   inflating: /content/full_size/heic0815d.jpg
#   inflating: /content/full_size/potw1619a.jpg
#   inflating: /content/full_size/potw1117a.jpg
# ...

# %%
dataset_path = "/content/full_size"
dataset_name = "full_size"


# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}
# Out:
# Loading images from "/content/full_size"
# Error: Input images must have the same width and height
